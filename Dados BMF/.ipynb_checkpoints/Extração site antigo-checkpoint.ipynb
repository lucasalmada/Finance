# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 0)

# %%
df = pd.read_excel('Estatistico_pregao_2018-2019.xlsx')

# %%
df.head()
# Out:
#   Data do pregão Referência do Resumo  ...  Volume negociado Volume negociado em Dólar
# 0     2018-01-02                 D+1   ...                 0                         0
# 1     2018-01-02                 D+1   ...                 0                         0
# 2     2018-01-02                 D+1   ...                 0                         0
# 3     2018-01-02                 D+1   ...                 0                         0
# 4     2018-01-02                 D+1   ...                 0                         0
#
# [5 rows x 58 columns]

# %%
df = df[(df[['Percentagem de negócios Day Trade']] > 1).all(axis = 1)]

# %%
df[(df[['Referência do Resumo']] == 'ELET').all(axis = 1)]
# Out:
#       Data do pregão Referência do Resumo  ...  Volume negociado Volume negociado em Dólar
# 38        2018-01-02                 ELET  ...       18742218545                5732091184
# 96        2018-01-03                 ELET  ...       23710259820                7287616358
# 153       2018-01-04                 ELET  ...       21304352230                6592101068
# 210       2018-01-05                 ELET  ...       20890778180                6445980493
# 267       2018-01-08                 ELET  ...       19423199380                6002781278
# 324       2018-01-09                 ELET  ...       24769196030                7645521508
# 381       2018-01-10                 ELET  ...       26753592295                8240241567
# 438       2018-01-11                 ELET  ...       22740517295                7040189869
# 495       2018-01-12                 ELET  ...       27067394370                8406806339
# ...

# %%
plt.plot(df['Cotação do ajuste - dia atual'])
